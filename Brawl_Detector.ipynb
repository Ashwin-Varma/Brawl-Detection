# %% [markdown]
#                                 OVERALL AIM OF THE PROJECT
# The overall model aims to analyze video data by leveraging spatiotemporal features extracted using the I3D model, and then classifying the videos based on those features into categories such as "peace" or "brawl." Additionally, by integrating YOLOv3-based people detection, the system can provide further insights—such as counting the number of people present—which might be indicative of the intensity of a brawl.

# %% [markdown]
# The code imports necessary libraries (OpenCV, NumPy, TensorFlow, and TensorFlow Hub) and sets up some parameters like the dataset path, video categories, and input size/frame count expected by the I3D model. It loads the I3D (Inflated 3D ConvNet) model from TensorFlow Hub. This model is pre-trained on the Kinetics-400 dataset and is used for extracting spatiotemporal features from videos.
#
# The code iterates over two video categories ("peace" and "brawl"). For each video, it extracts frames using the helper function, normalizes them, and passes them through the I3D model to extract features.

# %%
import os
import glob
import cv2
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub

# Parameters
DATASET_PATH = r"C:\Users\Nitro 5\PycharmProjects\pythonProject1\Dataset"
CATEGORIES = ["peace", "brawl"]   # Folder names; 0: peace, 1: brawl
NUM_I3D_FRAMES = 64               # I3D expects 64 frames per video
FRAME_SIZE = (224, 224)           # I3D default input size

# Explicitly set signature to "default" so that we expect the default behavior.
i3d_url = "https://tfhub.dev/deepmind/i3d-kinetics-400/1"
i3d_layer = hub.KerasLayer(i3d_url, trainable=False, signature="default")

def load_video_frames_i3d(video_path, num_frames=NUM_I3D_FRAMES, size=FRAME_SIZE):
    """
    Loads a video, samples or pads to `num_frames` frames, resizes each frame to `size`,
    and returns an array of frames.
    """
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    if total_frames <= 0:
        cap.release()
        return None

    # Uniform sampling indices (if video has fewer frames, use all available indices)
    if total_frames >= num_frames:
        frame_indices = np.linspace(0, total_frames - 1, num_frames, dtype=int)
    else:
        frame_indices = np.arange(total_frames)

    frames = []
    frame_id = 0
    ret = True
    while ret:
        ret, frame = cap.read()
        if not ret:
            break
        if frame_id in frame_indices:
            frame = cv2.resize(frame, size)
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(frame)
        frame_id += 1
    cap.release()

    # Pad with the last frame if fewer than num_frames
    if len(frames) < num_frames:
        last_frame = frames[-1] if frames else np.zeros((size[1], size[0], 3), dtype=np.uint8)
        for _ in range(num_frames - len(frames)):
            frames.append(last_frame)
    
    return np.array(frames)

# Lists to store extracted features and corresponding labels
video_features = []
video_labels = []

for label, category in enumerate(CATEGORIES):
    folder_path = os.path.join(DATASET_PATH, category)
    video_files = glob.glob(os.path.join(folder_path, "*.mp4"))  # Adjust extension if needed
    print(f"Processing {len(video_files)} videos in category '{category}'...")
    for video_path in video_files:
        frames = load_video_frames_i3d(video_path)
        if frames is not None:
            # Normalize frames to [0,1]
            frames = frames.astype('float32') / 255.0
            # Expand dims to create a batch of size 1: shape becomes (1, 64, 224, 224, 3)
            video_tensor = np.expand_dims(frames, axis=0)
            # Extract features using the I3D model (returns a tensor directly)
            features_tensor = i3d_layer(video_tensor)
            # Convert tensor to numpy array and remove batch dimension
            features = np.squeeze(features_tensor.numpy())
            video_features.append(features)
            video_labels.append(label)
        else:
            print(f"Warning: Could not load video: {video_path}")

video_features = np.array(video_features)
video_labels = np.array(video_labels)

print("Extracted features shape:", video_features.shape)
print("Labels shape:", video_labels.shape)

# Save the features and labels for later training
np.save("i3d_video_features.npy", video_features)
np.save("i3d_video_labels.npy", video_labels)
print("I3D feature extraction complete and data saved.")
# Out:
# Processing 800 videos in category 'peace'...
# Processing 800 videos in category 'brawl'...
# Extracted features shape: (1600, 400)
# Labels shape: (1600,)
# I3D feature extraction complete and data saved.

# %% [markdown]
# This code loads pre-extracted I3D video features and their corresponding labels, then builds, trains, and evaluates a simple Multi-Layer Perceptron (MLP) classifier to distinguish between two classes ("peace" vs. "brawl"). It uses an 80/20 train-test split-ratio , employs callbacks for early stopping and model checkpointing, and finally computes evaluation metrics such as accuracy, F1 score, confusion matrix, and a detailed classification report before saving the final model.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, classification_report, confusion_matrix

# Load the extracted I3D features and labels
features = np.load("i3d_video_features.npy")  # shape: (num_videos, feature_dim)
labels = np.load("i3d_video_labels.npy")        # shape: (num_videos,)

print("Features shape:", features.shape)
print("Labels shape:", labels.shape)

# Split data into training and testing sets (80/20 split)
X_train, X_test, y_train, y_test = train_test_split(
    features, labels, test_size=0.2, random_state=42, stratify=labels
)

# Build a simple MLP classifier on top of the I3D features
model = Sequential([
    Dense(256, activation='relu', input_shape=(features.shape[1],)),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # Binary classification (peace:0, brawl:1)
])

# Compile the model with Adam optimizer and binary crossentropy loss
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()

# Define callbacks for early stopping and saving the best model
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1),
    ModelCheckpoint("best_i3d_classifier.h5", monitor='val_loss', save_best_only=True, verbose=1)
]

# Train the classifier
history = model.fit(
    X_train, y_train,
    validation_split=0.1,
    epochs=50,
    batch_size=16,
    callbacks=callbacks,
    verbose=1
)

# Evaluate the classifier on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")

# Generate predictions on the test set
y_pred_probs = model.predict(X_test)
y_pred = (y_pred_probs > 0.5).astype(int).flatten()

# Calculate F1 score and print evaluation metrics
f1 = f1_score(y_test, y_pred)
print(f"F1 Score: {f1:.4f}")

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("Classification Report:")
print(classification_report(y_test, y_pred))

# Save the final trained model
model.save("final_i3d_classifier.h5")
print("Model training complete and model saved.")
# Out:
# Features shape: (1600, 400)
# Labels shape: (1600,)
# C:\Users\Nitro 5\venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 256)            │       102,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 135,681 (530.00 KB)
#  Trainable params: 135,681 (530.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 35/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5698 - loss: 2.1089
# Epoch 1: val_loss improved from inf to 0.40528, saving model to best_i3d_classifier.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5877 - loss: 1.9433 - val_accuracy: 0.8359 - val_loss: 0.4053
# Epoch 2/50
# 70/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7469 - loss: 1.0096
# Epoch 2: val_loss improved from 0.40528 to 0.28674, saving model to best_i3d_classifier.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7469 - loss: 1.0068 - val_accuracy: 0.8516 - val_loss: 0.2867
# Epoch 3/50
# 67/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7710 - loss: 0.8057
# Epoch 3: val_loss improved from 0.28674 to 0.22963, saving model to best_i3d_classifier.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7720 - loss: 0.8003 - val_accuracy: 0.8828 - val_loss: 0.2296
# Epoch 4/50
# 65/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7844 - loss: 0.6462
# Epoch 4: val_loss improved from 0.22963 to 0.19343, saving model to best_i3d_classifier.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7856 - loss: 0.6457 - val_accuracy: 0.9219 - val_loss: 0.1934
# Epoch 5/50
# 68/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8256 - loss: 0.5442
# Epoch 5: val_loss improved from 0.19343 to 0.16390, saving model to best_i3d_classifier.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8264 - loss: 0.5411 - val_accuracy: 0.9375 - val_loss: 0.1639
# Epoch 6/50
# 38/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8828 - loss: 0.3527
# Epoch 6: val_loss improved from 0.16390 to 0.14739, saving model to best_i3d_classifier.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8677 - loss: 0.3952 - val_accuracy: 0.9453 - val_loss: 0.1474
# Epoch 7/50
# 39/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8699 - loss: 0.3398
# Epoch 7: val_loss improved from 0.14739 to 0.13170, saving model to best_i3d_classifier.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8670 - loss: 0.3454 - val_accuracy: 0.9453 - val_loss: 0.1317
# Epoch 8/50
# 38/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8975 - loss: 0.3213
# Epoch 8: val_loss improved from 0.13170 to 0.12063, saving model to best_i3d_classifier.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8876 - loss: 0.3315 - val_accuracy: 0.9453 - val_loss: 0.1206
# Epoch 9/50
# 38/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8925 - loss: 0.2710
# Epoch 9: val_loss improved from 0.12063 to 0.11351, saving model to best_i3d_classifier.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8908 - loss: 0.2803 - val_accuracy: 0.9453 - val_loss: 0.1135
# Epoch 10/50
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8885 - loss: 0.3333
# Epoch 10: val_loss improved from 0.11351 to 0.10677, saving model to best_i3d_classifier.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8886 - loss: 0.3325 - val_accuracy: 0.9453 - val_loss: 0.1068
# Epoch 11/50
# 39/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9181 - loss: 0.2107
# Epoch 11: val_loss improved from 0.10677 to 0.10520, saving model to best_i3d_classifier.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9146 - loss: 0.2299 - val_accuracy: 0.9531 - val_loss: 0.1052
# Epoch 12/50
# 39/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9062 - loss: 0.2374
# Epoch 12: val_loss did not improve from 0.10520
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9093 - loss: 0.2367 - val_accuracy: 0.9531 - val_loss: 0.1077
# Epoch 13/50
# 41/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8991 - loss: 0.2790
# Epoch 13: val_loss improved from 0.10520 to 0.10090, saving model to best_i3d_classifier.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9066 - loss: 0.2593 - val_accuracy: 0.9531 - val_loss: 0.1009
# Epoch 14/50
# 40/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9119 - loss: 0.2070
# Epoch 14: val_loss did not improve from 0.10090
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9129 - loss: 0.2105 - val_accuracy: 0.9531 - val_loss: 0.1032
# Epoch 15/50
# 42/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9049 - loss: 0.2638
# Epoch 15: val_loss improved from 0.10090 to 0.09716, saving model to best_i3d_classifier.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.2365 - val_accuracy: 0.9531 - val_loss: 0.0972
# Epoch 16/50
# 41/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9226 - loss: 0.2184
# Epoch 16: val_loss improved from 0.09716 to 0.09582, saving model to best_i3d_classifier.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9273 - loss: 0.2003 - val_accuracy: 0.9609 - val_loss: 0.0958
# Epoch 17/50
# 39/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9196 - loss: 0.2191
# Epoch 17: val_loss improved from 0.09582 to 0.08521, saving model to best_i3d_classifier.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9236 - loss: 0.2027 - val_accuracy: 0.9688 - val_loss: 0.0852
# Epoch 18/50
# 36/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9412 - loss: 0.1478
# Epoch 18: val_loss did not improve from 0.08521
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9374 - loss: 0.1492 - val_accuracy: 0.9609 - val_loss: 0.0869
# Epoch 19/50
# 37/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9437 - loss: 0.1957
# Epoch 19: val_loss did not improve from 0.08521
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9422 - loss: 0.1845 - val_accuracy: 0.9688 - val_loss: 0.0852
# Epoch 20/50
# 42/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9625 - loss: 0.0878
# Epoch 20: val_loss did not improve from 0.08521
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9571 - loss: 0.1029 - val_accuracy: 0.9609 - val_loss: 0.0911
# Epoch 21/50
# 41/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9523 - loss: 0.1777
# Epoch 21: val_loss did not improve from 0.08521
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9485 - loss: 0.1648 - val_accuracy: 0.9609 - val_loss: 0.0854
# Epoch 22/50
# 39/72 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9424 - loss: 0.1176
# Epoch 22: val_loss did not improve from 0.08521
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9451 - loss: 0.1202 - val_accuracy: 0.9609 - val_loss: 0.0882
# Epoch 22: early stopping
# Restoring model weights from the end of the best epoch: 17.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9368 - loss: 0.1610
# Test Loss: 0.1663, Test Accuracy: 0.9312
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# F1 Score: 0.9345
# Confusion Matrix:
# [[141  19]
#  [  3 157]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.93       160
#            1       0.89      0.98      0.93       160
#
#     accuracy                           0.93       320
#    macro avg       0.94      0.93      0.93       320
# weighted avg       0.94      0.93      0.93       320
#
# Model training complete and model saved.

# %%
model.save("final_i3d_classifier.keras")
print("Model training complete and model saved.")
# Out:
# Model training complete and model saved.

# %%
import os
import glob
import numpy as np
import cv2
import tensorflow as tf
import tensorflow_hub as hub

# Load trained classifier model
model = tf.keras.models.load_model("final_i3d_classifier.keras")

# Load I3D feature extractor
i3d_url = "https://tfhub.dev/deepmind/i3d-kinetics-400/1"
i3d_layer = hub.KerasLayer(i3d_url, trainable=False, signature="default")

# Parameters
TEST_DATASET_PATH = r"C:\Users\Nitro 5\PycharmProjects\pythonProject1\Test"
NUM_I3D_FRAMES = 64  # I3D expects 64 frames
FRAME_SIZE = (224, 224)  # I3D default input size
# Out:
# C:\Users\Nitro 5\venv\Lib\site-packages\keras\src\saving\saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 8 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# WARNING:tensorflow:From C:\Users\Nitro 5\venv\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From C:\Users\Nitro 5\venv\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From C:\Users\Nitro 5\venv\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From C:\Users\Nitro 5\venv\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From C:\Users\Nitro 5\venv\Lib\site-packages\tf_keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# WARNING:tensorflow:From C:\Users\Nitro 5\venv\Lib\site-packages\tf_keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
def load_video_frames_i3d(video_path, num_frames=NUM_I3D_FRAMES, size=FRAME_SIZE):
    """
    Loads a video from a given path, samples/pads it to `num_frames`,
    resizes frames to `size`, converts them to RGB, and returns a NumPy array.
    """
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    if total_frames <= 0:
        cap.release()
        return None

    # Sample frames uniformly if enough frames exist; otherwise use all frames
    if total_frames >= num_frames:
        frame_indices = np.linspace(0, total_frames - 1, num_frames, dtype=int)
    else:
        frame_indices = np.arange(total_frames)

    frames = []
    frame_id = 0
    ret = True
    while ret:
        ret, frame = cap.read()
        if not ret:
            break
        if frame_id in frame_indices:
            frame = cv2.resize(frame, size)
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(frame)
        frame_id += 1
    cap.release()

    # Pad with the last frame if too few frames are available
    if len(frames) < num_frames:
        last_frame = frames[-1] if frames else np.zeros((size[1], size[0], 3), dtype=np.uint8)
        for _ in range(num_frames - len(frames)):
            frames.append(last_frame)

    return np.array(frames)

# %%
# Lists to store predictions and video paths
test_features = []
video_paths = []

# Get list of all video files in the Test folder (update extension if needed)
video_files = glob.glob(os.path.join(TEST_DATASET_PATH, "*.mp4"))
print(f"Processing {len(video_files)} videos from the Test folder...")

for video_path in video_files:
    frames = load_video_frames_i3d(video_path)
    if frames is not None:
        # Normalize frames to [0, 1]
        frames = frames.astype('float32') / 255.0
        # Expand dims to create a batch of size 1: shape (1, 64, 224, 224, 3)
        video_tensor = np.expand_dims(frames, axis=0)
        # Extract I3D features
        features_tensor = i3d_layer(video_tensor)
        # Convert to numpy array and remove batch dimension
        features = np.squeeze(features_tensor.numpy())
        test_features.append(features)
        video_paths.append(video_path)
    else:
        print(f"Warning: Could not load video: {video_path}")

# Convert test_features to a NumPy array
test_features = np.array(test_features)
print("Test features shape:", test_features.shape)

# Make predictions
pred_probs = model.predict(test_features)
pred_labels = (pred_probs > 0.5).astype(int).flatten()

# Optionally, print predictions alongside video paths
for path, pred in zip(video_paths, pred_labels):
    print(f"Video: {os.path.basename(path)} - Prediction: {pred}")
# Out:
# Processing 400 videos from the Test folder...
# Test features shape: (400, 400)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Video: Video_1.mp4 - Prediction: 0
# Video: Video_10.mp4 - Prediction: 0
# Video: Video_100.mp4 - Prediction: 1
# Video: Video_101.mp4 - Prediction: 0
# Video: Video_102.mp4 - Prediction: 1
# Video: Video_103.mp4 - Prediction: 0
# Video: Video_104.mp4 - Prediction: 0
# Video: Video_105.mp4 - Prediction: 1
# Video: Video_106.mp4 - Prediction: 1
# Video: Video_107.mp4 - Prediction: 1
# Video: Video_108.mp4 - Prediction: 1
# Video: Video_109.mp4 - Prediction: 0
# Video: Video_11.mp4 - Prediction: 1
# Video: Video_110.mp4 - Prediction: 1
# Video: Video_111.mp4 - Prediction: 1
# Video: Video_112.mp4 - Prediction: 0
# Video: Video_113.mp4 - Prediction: 1
# Video: Video_114.mp4 - Prediction: 0
# Video: Video_115.mp4 - Prediction: 0
# Video: Video_116.mp4 - Prediction: 1
# Video: Video_117.mp4 - Prediction: 0
# Video: Video_118.mp4 - Prediction: 1
# Video: Video_119.mp4 - Prediction: 0
# Video: Video_12.mp4 - Prediction: 0
# Video: Video_120.mp4 - Prediction: 1
# Video: Video_121.mp4 - Prediction: 0
# Video: Video_122.mp4 - Prediction: 0
# Video: Video_123.mp4 - Prediction: 0
# Video: Video_124.mp4 - Prediction: 1
# Video: Video_125.mp4 - Prediction: 0
# Video: Video_126.mp4 - Prediction: 1
# Video: Video_127.mp4 - Prediction: 1
# Video: Video_128.mp4 - Prediction: 1
# Video: Video_129.mp4 - Prediction: 1
# Video: Video_13.mp4 - Prediction: 1
# Video: Video_130.mp4 - Prediction: 0
# Video: Video_131.mp4 - Prediction: 1
# Video: Video_132.mp4 - Prediction: 1
# Video: Video_133.mp4 - Prediction: 0
# Video: Video_134.mp4 - Prediction: 1
# Video: Video_135.mp4 - Prediction: 0
# Video: Video_136.mp4 - Prediction: 0
# Video: Video_137.mp4 - Prediction: 0
# Video: Video_138.mp4 - Prediction: 1
# Video: Video_139.mp4 - Prediction: 1
# Video: Video_14.mp4 - Prediction: 1
# Video: Video_140.mp4 - Prediction: 1
# Video: Video_141.mp4 - Prediction: 0
# Video: Video_142.mp4 - Prediction: 0
# Video: Video_143.mp4 - Prediction: 1
# Video: Video_144.mp4 - Prediction: 0
# Video: Video_145.mp4 - Prediction: 0
# Video: Video_146.mp4 - Prediction: 1
# Video: Video_147.mp4 - Prediction: 1
# Video: Video_148.mp4 - Prediction: 1
# Video: Video_149.mp4 - Prediction: 0
# Video: Video_15.mp4 - Prediction: 1
# Video: Video_150.mp4 - Prediction: 0
# Video: Video_151.mp4 - Prediction: 0
# Video: Video_152.mp4 - Prediction: 1
# Video: Video_153.mp4 - Prediction: 0
# Video: Video_154.mp4 - Prediction: 1
# Video: Video_155.mp4 - Prediction: 1
# Video: Video_156.mp4 - Prediction: 1
# Video: Video_157.mp4 - Prediction: 1
# Video: Video_158.mp4 - Prediction: 1
# Video: Video_159.mp4 - Prediction: 1
# Video: Video_16.mp4 - Prediction: 0
# Video: Video_160.mp4 - Prediction: 0
# Video: Video_161.mp4 - Prediction: 0
# Video: Video_162.mp4 - Prediction: 1
# Video: Video_163.mp4 - Prediction: 0
# Video: Video_164.mp4 - Prediction: 0
# Video: Video_165.mp4 - Prediction: 0
# Video: Video_166.mp4 - Prediction: 0
# Video: Video_167.mp4 - Prediction: 1
# Video: Video_168.mp4 - Prediction: 1
# Video: Video_169.mp4 - Prediction: 1
# Video: Video_17.mp4 - Prediction: 1
# Video: Video_170.mp4 - Prediction: 1
# Video: Video_171.mp4 - Prediction: 0
# Video: Video_172.mp4 - Prediction: 1
# Video: Video_173.mp4 - Prediction: 0
# Video: Video_174.mp4 - Prediction: 1
# Video: Video_175.mp4 - Prediction: 0
# Video: Video_176.mp4 - Prediction: 1
# Video: Video_177.mp4 - Prediction: 1
# Video: Video_178.mp4 - Prediction: 0
# Video: Video_179.mp4 - Prediction: 0
# Video: Video_18.mp4 - Prediction: 0
# Video: Video_180.mp4 - Prediction: 1
# Video: Video_181.mp4 - Prediction: 0
# Video: Video_182.mp4 - Prediction: 0
# Video: Video_183.mp4 - Prediction: 0
# Video: Video_184.mp4 - Prediction: 0
# Video: Video_185.mp4 - Prediction: 1
# Video: Video_186.mp4 - Prediction: 1
# Video: Video_187.mp4 - Prediction: 0
# Video: Video_188.mp4 - Prediction: 1
# Video: Video_189.mp4 - Prediction: 1
# Video: Video_19.mp4 - Prediction: 1
# Video: Video_190.mp4 - Prediction: 1
# Video: Video_191.mp4 - Prediction: 0
# Video: Video_192.mp4 - Prediction: 0
# Video: Video_193.mp4 - Prediction: 1
# Video: Video_194.mp4 - Prediction: 0
# Video: Video_195.mp4 - Prediction: 1
# Video: Video_196.mp4 - Prediction: 1
# Video: Video_197.mp4 - Prediction: 1
# Video: Video_198.mp4 - Prediction: 0
# Video: Video_199.mp4 - Prediction: 0
# Video: Video_2.mp4 - Prediction: 1
# Video: Video_20.mp4 - Prediction: 0
# Video: Video_200.mp4 - Prediction: 0
# Video: Video_201.mp4 - Prediction: 0
# Video: Video_202.mp4 - Prediction: 1
# Video: Video_203.mp4 - Prediction: 0
# Video: Video_204.mp4 - Prediction: 0
# Video: Video_205.mp4 - Prediction: 0
# Video: Video_206.mp4 - Prediction: 0
# Video: Video_207.mp4 - Prediction: 0
# Video: Video_208.mp4 - Prediction: 1
# Video: Video_209.mp4 - Prediction: 0
# Video: Video_21.mp4 - Prediction: 1
# Video: Video_210.mp4 - Prediction: 0
# Video: Video_211.mp4 - Prediction: 0
# Video: Video_212.mp4 - Prediction: 0
# Video: Video_213.mp4 - Prediction: 1
# Video: Video_214.mp4 - Prediction: 1
# Video: Video_215.mp4 - Prediction: 1
# Video: Video_216.mp4 - Prediction: 1
# Video: Video_217.mp4 - Prediction: 1
# Video: Video_218.mp4 - Prediction: 0
# Video: Video_219.mp4 - Prediction: 1
# Video: Video_22.mp4 - Prediction: 1
# Video: Video_220.mp4 - Prediction: 0
# Video: Video_221.mp4 - Prediction: 0
# Video: Video_222.mp4 - Prediction: 0
# Video: Video_223.mp4 - Prediction: 0
# Video: Video_224.mp4 - Prediction: 1
# Video: Video_225.mp4 - Prediction: 0
# Video: Video_226.mp4 - Prediction: 0
# Video: Video_227.mp4 - Prediction: 0
# Video: Video_228.mp4 - Prediction: 1
# Video: Video_229.mp4 - Prediction: 0
# Video: Video_23.mp4 - Prediction: 1
# Video: Video_230.mp4 - Prediction: 1
# Video: Video_231.mp4 - Prediction: 0
# Video: Video_232.mp4 - Prediction: 1
# Video: Video_233.mp4 - Prediction: 0
# Video: Video_234.mp4 - Prediction: 1
# Video: Video_235.mp4 - Prediction: 0
# Video: Video_236.mp4 - Prediction: 1
# Video: Video_237.mp4 - Prediction: 1
# Video: Video_238.mp4 - Prediction: 1
# Video: Video_239.mp4 - Prediction: 0
# Video: Video_24.mp4 - Prediction: 0
# Video: Video_240.mp4 - Prediction: 0
# Video: Video_241.mp4 - Prediction: 1
# Video: Video_242.mp4 - Prediction: 0
# Video: Video_243.mp4 - Prediction: 0
# Video: Video_244.mp4 - Prediction: 1
# Video: Video_245.mp4 - Prediction: 1
# Video: Video_246.mp4 - Prediction: 0
# Video: Video_247.mp4 - Prediction: 0
# Video: Video_248.mp4 - Prediction: 0
# Video: Video_249.mp4 - Prediction: 1
# Video: Video_25.mp4 - Prediction: 0
# Video: Video_250.mp4 - Prediction: 1
# Video: Video_251.mp4 - Prediction: 0
# Video: Video_252.mp4 - Prediction: 1
# Video: Video_253.mp4 - Prediction: 1
# Video: Video_254.mp4 - Prediction: 1
# Video: Video_255.mp4 - Prediction: 1
# Video: Video_256.mp4 - Prediction: 0
# Video: Video_257.mp4 - Prediction: 1
# Video: Video_258.mp4 - Prediction: 0
# Video: Video_259.mp4 - Prediction: 1
# Video: Video_26.mp4 - Prediction: 1
# Video: Video_260.mp4 - Prediction: 1
# Video: Video_261.mp4 - Prediction: 1
# Video: Video_262.mp4 - Prediction: 1
# Video: Video_263.mp4 - Prediction: 1
# Video: Video_264.mp4 - Prediction: 0
# Video: Video_265.mp4 - Prediction: 1
# Video: Video_266.mp4 - Prediction: 1
# Video: Video_267.mp4 - Prediction: 1
# Video: Video_268.mp4 - Prediction: 0
# Video: Video_269.mp4 - Prediction: 1
# Video: Video_27.mp4 - Prediction: 1
# Video: Video_270.mp4 - Prediction: 1
# Video: Video_271.mp4 - Prediction: 0
# Video: Video_272.mp4 - Prediction: 1
# Video: Video_273.mp4 - Prediction: 1
# Video: Video_274.mp4 - Prediction: 1
# Video: Video_275.mp4 - Prediction: 1
# Video: Video_276.mp4 - Prediction: 0
# Video: Video_277.mp4 - Prediction: 0
# Video: Video_278.mp4 - Prediction: 1
# Video: Video_279.mp4 - Prediction: 0
# Video: Video_28.mp4 - Prediction: 0
# Video: Video_280.mp4 - Prediction: 1
# Video: Video_281.mp4 - Prediction: 1
# Video: Video_282.mp4 - Prediction: 1
# Video: Video_283.mp4 - Prediction: 1
# Video: Video_284.mp4 - Prediction: 0
# Video: Video_285.mp4 - Prediction: 0
# Video: Video_286.mp4 - Prediction: 0
# Video: Video_287.mp4 - Prediction: 0
# Video: Video_288.mp4 - Prediction: 1
# Video: Video_289.mp4 - Prediction: 1
# Video: Video_29.mp4 - Prediction: 0
# Video: Video_290.mp4 - Prediction: 1
# Video: Video_291.mp4 - Prediction: 1
# Video: Video_292.mp4 - Prediction: 1
# Video: Video_293.mp4 - Prediction: 1
# Video: Video_294.mp4 - Prediction: 1
# Video: Video_295.mp4 - Prediction: 0
# Video: Video_296.mp4 - Prediction: 0
# Video: Video_297.mp4 - Prediction: 1
# Video: Video_298.mp4 - Prediction: 0
# Video: Video_299.mp4 - Prediction: 0
# Video: Video_3.mp4 - Prediction: 1
# Video: Video_30.mp4 - Prediction: 0
# Video: Video_300.mp4 - Prediction: 0
# Video: Video_301.mp4 - Prediction: 1
# Video: Video_302.mp4 - Prediction: 0
# Video: Video_303.mp4 - Prediction: 1
# Video: Video_304.mp4 - Prediction: 1
# Video: Video_305.mp4 - Prediction: 1
# Video: Video_306.mp4 - Prediction: 1
# Video: Video_307.mp4 - Prediction: 1
# Video: Video_308.mp4 - Prediction: 1
# Video: Video_309.mp4 - Prediction: 1
# Video: Video_31.mp4 - Prediction: 1
# Video: Video_310.mp4 - Prediction: 0
# Video: Video_311.mp4 - Prediction: 0
# Video: Video_312.mp4 - Prediction: 0
# Video: Video_313.mp4 - Prediction: 1
# Video: Video_314.mp4 - Prediction: 1
# Video: Video_315.mp4 - Prediction: 1
# Video: Video_316.mp4 - Prediction: 1
# Video: Video_317.mp4 - Prediction: 1
# Video: Video_318.mp4 - Prediction: 0
# Video: Video_319.mp4 - Prediction: 0
# Video: Video_32.mp4 - Prediction: 0
# Video: Video_320.mp4 - Prediction: 0
# Video: Video_321.mp4 - Prediction: 0
# Video: Video_322.mp4 - Prediction: 0
# Video: Video_323.mp4 - Prediction: 1
# Video: Video_324.mp4 - Prediction: 1
# Video: Video_325.mp4 - Prediction: 1
# Video: Video_326.mp4 - Prediction: 0
# Video: Video_327.mp4 - Prediction: 1
# Video: Video_328.mp4 - Prediction: 0
# Video: Video_329.mp4 - Prediction: 0
# Video: Video_33.mp4 - Prediction: 1
# Video: Video_330.mp4 - Prediction: 0
# Video: Video_331.mp4 - Prediction: 0
# Video: Video_332.mp4 - Prediction: 0
# Video: Video_333.mp4 - Prediction: 0
# Video: Video_334.mp4 - Prediction: 1
# Video: Video_335.mp4 - Prediction: 1
# Video: Video_336.mp4 - Prediction: 0
# Video: Video_337.mp4 - Prediction: 0
# Video: Video_338.mp4 - Prediction: 0
# Video: Video_339.mp4 - Prediction: 1
# Video: Video_34.mp4 - Prediction: 1
# Video: Video_340.mp4 - Prediction: 1
# Video: Video_341.mp4 - Prediction: 1
# Video: Video_342.mp4 - Prediction: 0
# Video: Video_343.mp4 - Prediction: 1
# Video: Video_344.mp4 - Prediction: 1
# Video: Video_345.mp4 - Prediction: 1
# Video: Video_346.mp4 - Prediction: 0
# Video: Video_347.mp4 - Prediction: 1
# Video: Video_348.mp4 - Prediction: 0
# Video: Video_349.mp4 - Prediction: 0
# Video: Video_35.mp4 - Prediction: 1
# Video: Video_350.mp4 - Prediction: 0
# Video: Video_351.mp4 - Prediction: 0
# Video: Video_352.mp4 - Prediction: 0
# Video: Video_353.mp4 - Prediction: 1
# Video: Video_354.mp4 - Prediction: 0
# Video: Video_355.mp4 - Prediction: 1
# Video: Video_356.mp4 - Prediction: 1
# Video: Video_357.mp4 - Prediction: 1
# Video: Video_358.mp4 - Prediction: 1
# Video: Video_359.mp4 - Prediction: 0
# Video: Video_36.mp4 - Prediction: 0
# Video: Video_360.mp4 - Prediction: 1
# Video: Video_361.mp4 - Prediction: 1
# Video: Video_362.mp4 - Prediction: 0
# Video: Video_363.mp4 - Prediction: 1
# Video: Video_364.mp4 - Prediction: 1
# Video: Video_365.mp4 - Prediction: 0
# Video: Video_366.mp4 - Prediction: 0
# Video: Video_367.mp4 - Prediction: 0
# Video: Video_368.mp4 - Prediction: 0
# Video: Video_369.mp4 - Prediction: 1
# Video: Video_37.mp4 - Prediction: 1
# Video: Video_370.mp4 - Prediction: 1
# Video: Video_371.mp4 - Prediction: 1
# Video: Video_372.mp4 - Prediction: 1
# Video: Video_373.mp4 - Prediction: 1
# Video: Video_374.mp4 - Prediction: 0
# Video: Video_375.mp4 - Prediction: 0
# Video: Video_376.mp4 - Prediction: 1
# Video: Video_377.mp4 - Prediction: 0
# Video: Video_378.mp4 - Prediction: 0
# Video: Video_379.mp4 - Prediction: 1
# Video: Video_38.mp4 - Prediction: 1
# Video: Video_380.mp4 - Prediction: 1
# Video: Video_381.mp4 - Prediction: 1
# Video: Video_382.mp4 - Prediction: 1
# Video: Video_383.mp4 - Prediction: 1
# Video: Video_384.mp4 - Prediction: 1
# Video: Video_385.mp4 - Prediction: 0
# Video: Video_386.mp4 - Prediction: 0
# Video: Video_387.mp4 - Prediction: 1
# Video: Video_388.mp4 - Prediction: 0
# Video: Video_389.mp4 - Prediction: 0
# Video: Video_39.mp4 - Prediction: 1
# Video: Video_390.mp4 - Prediction: 0
# Video: Video_391.mp4 - Prediction: 1
# Video: Video_392.mp4 - Prediction: 0
# Video: Video_393.mp4 - Prediction: 1
# Video: Video_394.mp4 - Prediction: 1
# Video: Video_395.mp4 - Prediction: 0
# Video: Video_396.mp4 - Prediction: 0
# Video: Video_397.mp4 - Prediction: 1
# Video: Video_398.mp4 - Prediction: 1
# Video: Video_399.mp4 - Prediction: 1
# Video: Video_4.mp4 - Prediction: 1
# Video: Video_40.mp4 - Prediction: 1
# Video: Video_400.mp4 - Prediction: 1
# Video: Video_41.mp4 - Prediction: 0
# Video: Video_42.mp4 - Prediction: 0
# Video: Video_43.mp4 - Prediction: 0
# Video: Video_44.mp4 - Prediction: 0
# Video: Video_45.mp4 - Prediction: 0
# Video: Video_46.mp4 - Prediction: 0
# Video: Video_47.mp4 - Prediction: 1
# Video: Video_48.mp4 - Prediction: 1
# Video: Video_49.mp4 - Prediction: 0
# Video: Video_5.mp4 - Prediction: 1
# Video: Video_50.mp4 - Prediction: 1
# Video: Video_51.mp4 - Prediction: 0
# Video: Video_52.mp4 - Prediction: 1
# Video: Video_53.mp4 - Prediction: 0
# Video: Video_54.mp4 - Prediction: 1
# Video: Video_55.mp4 - Prediction: 1
# Video: Video_56.mp4 - Prediction: 0
# Video: Video_57.mp4 - Prediction: 0
# Video: Video_58.mp4 - Prediction: 1
# Video: Video_59.mp4 - Prediction: 0
# Video: Video_6.mp4 - Prediction: 1
# Video: Video_60.mp4 - Prediction: 1
# Video: Video_61.mp4 - Prediction: 0
# Video: Video_62.mp4 - Prediction: 0
# Video: Video_63.mp4 - Prediction: 0
# Video: Video_64.mp4 - Prediction: 1
# Video: Video_65.mp4 - Prediction: 1
# Video: Video_66.mp4 - Prediction: 1
# Video: Video_67.mp4 - Prediction: 1
# Video: Video_68.mp4 - Prediction: 1
# Video: Video_69.mp4 - Prediction: 1
# Video: Video_7.mp4 - Prediction: 1
# Video: Video_70.mp4 - Prediction: 1
# Video: Video_71.mp4 - Prediction: 0
# Video: Video_72.mp4 - Prediction: 1
# Video: Video_73.mp4 - Prediction: 1
# Video: Video_74.mp4 - Prediction: 0
# Video: Video_75.mp4 - Prediction: 1
# Video: Video_76.mp4 - Prediction: 0
# Video: Video_77.mp4 - Prediction: 0
# Video: Video_78.mp4 - Prediction: 1
# Video: Video_79.mp4 - Prediction: 0
# Video: Video_8.mp4 - Prediction: 0
# Video: Video_80.mp4 - Prediction: 1
# Video: Video_81.mp4 - Prediction: 1
# Video: Video_82.mp4 - Prediction: 0
# Video: Video_83.mp4 - Prediction: 1
# Video: Video_84.mp4 - Prediction: 0
# Video: Video_85.mp4 - Prediction: 1
# Video: Video_86.mp4 - Prediction: 1
# Video: Video_87.mp4 - Prediction: 1
# Video: Video_88.mp4 - Prediction: 1
# Video: Video_89.mp4 - Prediction: 0
# Video: Video_9.mp4 - Prediction: 1
# Video: Video_90.mp4 - Prediction: 1
# Video: Video_91.mp4 - Prediction: 1
# Video: Video_92.mp4 - Prediction: 0
# Video: Video_93.mp4 - Prediction: 1
# Video: Video_94.mp4 - Prediction: 0
# Video: Video_95.mp4 - Prediction: 0
# Video: Video_96.mp4 - Prediction: 0
# Video: Video_97.mp4 - Prediction: 1
# Video: Video_98.mp4 - Prediction: 0
# Video: Video_99.mp4 - Prediction: 1

# %%
import os
import numpy as np
import pandas as pd

# Generate video IDs from file names
video_ids = [os.path.basename(path) for path in video_paths]

# Map predictions (0 for peace, 1 for brawl)
predictions = ["peace" if p == 0 else "brawl" for p in pred_labels]

# Create DataFrame and save predictions to CSV
df = pd.DataFrame({"videoID": video_ids, "prediction": predictions})
df.to_csv("predictions.csv", index=False)

print("\nPredictions saved to predictions.csv")
# Out:
# Predictions saved to predictions.csv

# %%
import pandas as pd
import re

def extract_number(label):
    match = re.search(r'\d+', str(label))
    return int(match.group()) if match else 0

# Read the CSV file (replace 'input.csv' with your CSV filename)
df = pd.read_csv('predictions.csv')

# Extract numeric part and sort
df['numeric'] = df['videoID'].apply(extract_number)
df_sorted = df.sort_values('numeric').drop(columns=['numeric'])

# Save the sorted DataFrame to a new CSV file
df_sorted.to_csv('sorted_output.csv', index=False)
